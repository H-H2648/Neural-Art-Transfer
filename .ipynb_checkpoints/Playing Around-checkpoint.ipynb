# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
from PIL import Image
from ImageLoader import loadImage
# Out:
#   File "<ipython-input-5-1dcf87226bb8>", line 6
#     from Image-Loader import loadImage
#               ^
# SyntaxError: invalid syntax

# %%
content_img_path = r'C:\Users\hhong\Documents\Neural Art Transfer\content-images\cat.jpg'
content_img = mpimg.imread(content_img_path)
print(content_img)
plt.imshow(content_img)
print(content_img.shape)
# Out:
# [[[ 61  80  74]
#   [ 55  74  68]
#   [ 49  68  62]
#   ...
#   [161 163 149]
#   [161 163 149]
#   [161 163 149]]
#
#  [[ 65  84  78]
#   [ 61  80  74]
#   [ 55  74  68]
#   ...
#   [162 164 150]
#   [162 164 150]
#   [162 164 150]]
#
#  [[ 66  85  81]
#   [ 63  82  78]
#   [ 59  78  74]
#   ...
#   [162 164 150]
#   [162 164 150]
#   [162 164 150]]
#
#  ...
#
#  [[106  95  89]
#   [101  90  84]
#   [ 95  82  76]
#   ...
#   [ 76  79  84]
#   [ 83  86  91]
#   [ 89  92  97]]
#
#  [[108  95  89]
#   [103  90  84]
#   [ 94  81  75]
#   ...
#   [ 63  66  73]
#   [ 68  71  78]
#   [ 73  76  83]]
#
#  [[108  95  89]
#   [103  90  84]
#   [ 94  81  75]
#   ...
#   [ 60  63  70]
#   [ 64  67  74]
#   [ 68  71  78]]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-0e673a98cf29> in <module>
#       3 print(content_img)
#       4 plt.imshow(content_img)
# ...

# %%
cat = Image.open(content_img_path)
reCat = cat.resize((224, 224))
reCat
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x2492B400F70>

# %%
white_noise_img = np.random.uniform(-90., 90., content_img.shape).astype(np.float32)
imgplot = plt.imshow(white_noise_img)
